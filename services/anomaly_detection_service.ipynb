# %%
import matplotlib.pyplot as plt
import pandas as pd

csv_file_path = '../datasets/20250301-buses.csv'
columns_to_be_dropped = ['_id', 'vehicle.trip.trip_id', 'vehicle.position.speed', 'vehicle.vehicle.id',
                         'vehicle.congestion_level',]

data = pd.read_csv(csv_file_path)
data = data.drop(columns_to_be_dropped, axis=1)
data.head(10)
# Out:
#       id vehicle.trip.start_time  vehicle.trip.start_date  \
# 0  41053                08:30:00                 20250301
# 1  31841                08:51:00                 20250301
# 2  42027                08:48:00                 20250301
# 3  29850                09:14:00                 20250301
# 4  31117                08:19:00                 20250301
# 5  30862                08:28:00                 20250301
# 6  36001                08:48:00                 20250301
# 7  42029                08:32:00                 20250301
# 8  30834                08:25:00                 20250301
# 9  41080                09:02:00                 20250301
#
#    vehicle.trip.route_id  vehicle.position.latitude  \
# 0                    140                  45.568321
# 1                    121                  45.506229
# 2                    140                  45.566505
# 3                    121                  45.497978
# 4                    140                  45.606026
# 5                    121                  45.536247
# 6                     45                  45.533981
# 7                     45                  45.540760
# 8                    121                  45.513908
# 9                     45                  45.573563
#
#    vehicle.position.longitude  vehicle.current_stop_sequence  \
# 0                  -73.653305                             32
# 1                  -73.692696                              9
# 2                  -73.657669                             15
# 3                  -73.709808                              1
# 4                  -73.635910                             43
# 5                  -73.665375                             25
# 6                  -73.576859                             10
# 7                  -73.591476                             28
# 8                  -73.683311                             39
# 9                  -73.658623                              1
#
#    vehicle.current_status  vehicle.timestamp  vehicle.occupancy_status  \
# 0                       1         1740837663                         3
# 1                       1         1740837662                         1
# 2                       2         1740837660                         3
# 3                       1         1740837657                         1
# 4                       2         1740837655                         1
# 5                       2         1740837655                         2
# 6                       2         1740837654                         1
# 7                       1         1740837653                         1
# 8                       1         1740837649                         2
# 9                       1         1740837648                         1
#
#    vehicle.position.bearing
# 0                       NaN
# 1                      39.0
# 2                      28.0
# 3                     314.0
# 4                     325.0
# 5                       NaN
# 6                     303.0
# 7                       NaN
# 8                     225.0
# 9                       NaN
